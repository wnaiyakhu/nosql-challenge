# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
[x for x in db.establishments.find()]
# Out:
# [{'_id': ObjectId('650dc8bcc6437c7047185e5a'),
#   'FHRSID': 1034540,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078691',
#   'BusinessName': 'The Coastguard Inn',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Bay',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DY',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#   'RightToReply': '',
#   'Distance': 4587.347174863443,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1034540'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e5b'),
#   'FHRSID': 254719,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000069980',
#   'BusinessName': 'Refreshment Kiosk',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Bay',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DY',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-03-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#   'RightToReply': '',
#   'Distance': 4587.347174863443,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254719'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e5c'),
#   'FHRSID': 254250,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000066174',
#   'BusinessName': 'The Pines Calyx',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'The Pines Garden',
#   'AddressLine2': 'Beach Road',
#   'AddressLine3': 'St Margarets Bay',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6DZ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#   'RightToReply': '',
#   'Distance': 4587.362402580997,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254250'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e5d'),
#   'FHRSID': 551803,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070948',
#   'BusinessName': 'The Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'The Pines Garden',
#   'AddressLine2': 'Beach Road',
#   'AddressLine3': 'St Margarets Bay',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6DZ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.383298', 'latitude': '51.148133'},
#   'RightToReply': '',
#   'Distance': 4587.362402580997,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/551803'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e5e'),
#   'FHRSID': 466211,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000070896',
#   'BusinessName': 'The White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AT',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-12-03T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.372341', 'latitude': '51.153784'},
#   'RightToReply': '',
#   'Distance': 4587.973462119751,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/466211'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e5f'),
#   'FHRSID': 962759,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077707',
#   'BusinessName': 'The Village Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AU',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2020-03-05T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371543', 'latitude': '51.154023'},
#   'RightToReply': '',
#   'Distance': 4588.011450047919,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/962759'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e60'),
#   'FHRSID': 254731,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043588',
#   'BusinessName': 'The Smugglers',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'High Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6AU',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371543', 'latitude': '51.154023'},
#   'RightToReply': '',
#   'Distance': 4588.011450047919,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254731'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e61'),
#   'FHRSID': 1376311,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084109',
#   'BusinessName': "St Margaret's Bowls and Social Club",
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Bowling Club',
#   'AddressLine2': '13 Kingsdown Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AZ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-13T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.37213003635406', 'latitude': '51.1558113098145'},
#   'RightToReply': '',
#   'Distance': 4588.057641902885,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1376311'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e62'),
#   'FHRSID': 254239,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000068711',
#   'BusinessName': 'Boat House & Langdon',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'St Margarets Hotel And Country Club',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AG',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-07-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.366199', 'latitude': '51.150372'},
#   'RightToReply': '',
#   'Distance': 4588.067654106012,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254239'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e63'),
#   'FHRSID': 760657,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074489',
#   'BusinessName': 'The Lounge Bar',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2017-08-11T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/760657'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e64'),
#   'FHRSID': 1420231,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084856',
#   'BusinessName': 'Hogbox',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1420231'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e65'),
#   'FHRSID': 1205250,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000081301',
#   'BusinessName': 'Goodwins Suite (Reception)',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Kingsdown Park Holiday Village',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EU',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-10-24T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.402478', 'latitude': '51.185258'},
#   'RightToReply': '',
#   'Distance': 4588.0687557014535,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1205250'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e66'),
#   'FHRSID': 1051016,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078918',
#   'BusinessName': 'Rising Sun',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Cliffe Road',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8AH',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-09-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032', 'latitude': '51.186118'},
#   'RightToReply': '',
#   'Distance': 4588.075073437313,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1051016'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e67'),
#   'FHRSID': 522102,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000072342',
#   'BusinessName': 'Zetland Arms',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Wellington Parade',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8AF',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_3_en-gb',
#   'RatingDate': '2021-09-30T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.404353', 'latitude': '51.187776'},
#   'RightToReply': '',
#   'Distance': 4588.095921173912,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/522102'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e68'),
#   'FHRSID': 799986,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075312',
#   'BusinessName': 'Seahaven & Kingsdown Lodge',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'Beach House',
#   'AddressLine2': '110 Wellington Parade',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8AF',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-05T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4042455', 'latitude': '51.1886588'},
#   'RightToReply': '',
#   'Distance': 4588.13317786893,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/799986'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e69'),
#   'FHRSID': 607349,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073098',
#   'BusinessName': 'Oxtale',
#   'BusinessType': 'Manufacturers/packers',
#   'BusinessTypeID': 7839,
#   'AddressLine1': 'The Ox Tale Butchers',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2022-06-22T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185027'},
#   'RightToReply': '',
#   'Distance': 4588.155098195237,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/607349'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e6a'),
#   'FHRSID': 254315,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000066967',
#   'BusinessName': 'Kingsdown Pre School',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'St Johns Village Hall',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2017-09-18T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185028'},
#   'RightToReply': '',
#   'Distance': 4588.155135977967,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254315'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e6b'),
#   'FHRSID': 254372,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040981',
#   'BusinessName': 'Kings Head',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'Upper Street',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-16T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185028'},
#   'RightToReply': '',
#   'Distance': 4588.155135977967,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254372'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e6c'),
#   'FHRSID': 254344,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040950',
#   'BusinessName': 'Kingsdown Newsagents',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '1 Greenbank',
#   'AddressLine2': 'Upper Street',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8BJ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-12-12T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.399856', 'latitude': '51.185028'},
#   'RightToReply': '',
#   'Distance': 4588.155135977967,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254344'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e6d'),
#   'FHRSID': 254390,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000038162',
#   'BusinessName': 'National Trust White Cliffs',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Visitors Centre',
#   'AddressLine2': 'National Trust',
#   'AddressLine3': 'Langdon Cliffs',
#   'AddressLine4': 'Dover',
#   'PostCode': 'CT16 1HJ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.338963', 'latitude': '51.132101'},
#   'RightToReply': '',
#   'Distance': 4588.367605738605,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254390'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e6e'),
#   'FHRSID': 254227,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040455',
#   'BusinessName': 'Kingsdown And Ringwould Cofe Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Glen Road',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8DD',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-09-18T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.395204', 'latitude': '51.186575'},
#   'RightToReply': '',
#   'Distance': 4588.382262530662,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254227'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e6f'),
#   'FHRSID': 452108,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000071385',
#   'BusinessName': 'Kingsdown & Ringwould Breakfast Club',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Kingsdown And Ringwould Cofe Primary School',
#   'AddressLine2': 'Glen Road',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8DD',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-11-12T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.39520394802094', 'latitude': '51.1865768432617'},
#   'RightToReply': '',
#   'Distance': 4588.38233405188,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452108'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e70'),
#   'FHRSID': 632212,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043474',
#   'BusinessName': 'Lenox House',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': '27 Granville Road',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DS',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-03-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.385585', 'latitude': '51.152411'},
#   'RightToReply': '',
#   'Distance': 4587.440906956158,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/632212'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e71'),
#   'FHRSID': 429991,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000055200',
#   'BusinessName': 'Mrs Knotts Tea Room',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'West Cottage',
#   'AddressLine2': 'South Foreland Lighthouse',
#   'AddressLine3': 'The Front',
#   'AddressLine4': 'St Margarets Bay',
#   'PostCode': 'CT15 6HP',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-05-02T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371894', 'latitude': '51.14061'},
#   'RightToReply': '',
#   'Distance': 4587.492467848017,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429991'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e72'),
#   'FHRSID': 1349980,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000084064',
#   'BusinessName': 'Boodles',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '3 The Droveway',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DH',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-06-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.378536', 'latitude': '51.150879'},
#   'RightToReply': '',
#   'Distance': 4587.638929767669,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1349980'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e73'),
#   'FHRSID': 1290215,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000083029',
#   'BusinessName': 'FirstLight Bar & Café',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '1 The Droveway',
#   'AddressLine2': 'St Margarets Bay',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6DH',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-11-09T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.378231', 'latitude': '51.150625'},
#   'RightToReply': '',
#   'Distance': 4587.64041272672,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1290215'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e74'),
#   'FHRSID': 429982,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000043978',
#   'BusinessName': 'The Barn',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Reach Court Farm',
#   'AddressLine2': 'Reach Road',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6AQ',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-09-21T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.371115', 'latitude': '51.147379'},
#   'RightToReply': '',
#   'Distance': 4587.77622109052,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/429982'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e75'),
#   'FHRSID': 1531040,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000085904',
#   'BusinessName': 'The Halfway Hut',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer And Kingsdown Golf Club',
#   'AddressLine2': 'The Leas',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_awaitinginspection_en-gb',
#   'RatingDate': '1901-01-01T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032986', 'latitude': '51.1787284'},
#   'RightToReply': '',
#   'Distance': 4587.792282474894,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1531040'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e76'),
#   'FHRSID': 1273080,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000082753',
#   'BusinessName': 'Lovetocater',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Walmer And Kingsdown Golf Club',
#   'AddressLine2': 'The Leas',
#   'AddressLine3': 'Kingsdown',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-06-23T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.4032986', 'latitude': '51.1787284'},
#   'RightToReply': '',
#   'Distance': 4587.792282474894,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1273080'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e77'),
#   'FHRSID': 452092,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000040614',
#   'BusinessName': 'Walmer and Kingsdown Golf Club',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'AddressLine1': 'The Leas',
#   'AddressLine2': 'Kingsdown',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT14 8EP',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-09-10T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': None,
#    'Structural': None,
#    'ConfidenceInManagement': None},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.40325689315796', 'latitude': '51.1787300109863'},
#   'RightToReply': '',
#   'Distance': 4587.793855801259,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452092'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e78'),
#   'FHRSID': 254410,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000053944',
#   'BusinessName': 'St Margarets At Cliffe C P School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Sea Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6SS',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-01-16T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.375095', 'latitude': '51.152913'},
#   'RightToReply': '',
#   'Distance': 4587.840617011452,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254410'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e79'),
#   'FHRSID': 574015,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000069596',
#   'BusinessName': 'St Margarets At Cliffe Nursery And After School Club',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'St Margarets At Cliffe C P School',
#   'AddressLine2': 'Sea Street',
#   'AddressLine3': 'St Margarets At Cliffe',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT15 6SS',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-08-27T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.375095', 'latitude': '51.152913'},
#   'RightToReply': '',
#   'Distance': 4587.840617011452,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/574015'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e7a'),
#   'FHRSID': 1030622,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078259',
#   'BusinessName': 'Portal House School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'AddressLine1': 'Sea Street',
#   'AddressLine2': 'St Margarets At Cliffe',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT15 6SS',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-13T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.375095', 'latitude': '51.152913'},
#   'RightToReply': '',
#   'Distance': 4587.840617011452,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1030622'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e7b'),
#   'FHRSID': 452084,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024319',
#   'BusinessName': 'Costa Coffee',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Berth 8/9',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2017-11-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452084'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e7c'),
#   'FHRSID': 254219,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000054467',
#   'BusinessName': 'W H Smiths',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Terminal 3',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-10-17T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254219'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e7d'),
#   'FHRSID': 430031,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000071360',
#   'BusinessName': 'Spirit of France',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'P&O Ferries',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-06-07T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/430031'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e7e'),
#   'FHRSID': 254496,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000024155',
#   'BusinessName': 'Pride of Canterbury',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': 'P&O Ferries',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-09-23T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/254496'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e7f'),
#   'FHRSID': 452096,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000053923',
#   'BusinessName': 'Burger King',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Terminal 3',
#   'AddressLine2': 'Eastern Docks',
#   'AddressLine3': 'Dover',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT16 1JA',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-11-14T00:00:00',
#   'LocalAuthorityCode': '182',
#   'LocalAuthorityName': 'Dover',
#   'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#   'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.333158', 'latitude': '51.128318'},
#   'RightToReply': '',
#   'Distance': 4588.435903092498,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/452096'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047185e80'),
#   'FHRSID': 254693,
# ...
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289516'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047186236'),
#   'FHRSID': 1023910,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075939',
#   'BusinessName': 'Bengal Spice',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '73 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1023910'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047186237'),
#   'FHRSID': 894598,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000074407',
#   'BusinessName': 'Folkestone Rainbow Centre Pre-school',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'Salvation Army Citadel',
#   'AddressLine2': '75-79 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2018-09-13T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/894598'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047186238'),
#   'FHRSID': 1159687,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077229',
#   'BusinessName': "Roots 'n' Fruits",
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '73 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-18T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1159687'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047186239'),
#   'FHRSID': 1193486,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000077462',
#   'BusinessName': 'Rainbow Centre - Foodstop Service',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'AddressLine1': 'Salvation Army Citadel',
#   'AddressLine2': '75-79 Canterbury Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-10-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1193486'}]},
#  {'_id': ObjectId('650dc8bcc6437c704718623a'),
#   'FHRSID': 1384023,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000035614',
#   'BusinessName': 'Folkestone Food & Wine',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'AddressLine1': '70 Canterbury Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-05-17T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.1842719', 'latitude': '51.0881644'},
#   'RightToReply': '',
#   'Distance': 4592.342542316049,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1384023'}]},
#  {'_id': ObjectId('650dc8bcc6437c704718623b'),
#   'FHRSID': 947398,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075110',
#   'BusinessName': 'Clifton Hotel',
#   'BusinessType': 'Hotel/bed & breakfast/guest house',
#   'BusinessTypeID': 7842,
#   'AddressLine1': '1-6 Clifton Gardens',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2EB',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2020-01-08T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.172055', 'latitude': '51.076413'},
#   'RightToReply': '',
#   'Distance': 4592.3466239210875,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/947398'}]},
#  {'_id': ObjectId('650dc8bcc6437c704718623c'),
#   'FHRSID': 289518,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000035590',
#   'BusinessName': 'Salvation Army Citadel',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'AddressLine1': '75-79 Canterbury Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT19 5NL',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2022-08-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 0, 'ConfidenceInManagement': 0},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.18431', 'latitude': '51.088115'},
#   'RightToReply': '',
#   'Distance': 4592.339299517761,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/289518'}]},
#  {'_id': ObjectId('650dc8bcc6437c704718623d'),
#   'FHRSID': 1204285,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000076800',
#   'BusinessName': 'Sotirios Bar & Restaurant',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '2A Bouverie Road West',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2RX',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingDate': '2019-10-16T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 10, 'Structural': 0, 'ConfidenceInManagement': 10},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.174748', 'latitude': '51.079039'},
#   'RightToReply': '',
#   'Distance': 4592.347028349303,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1204285'}]},
#  {'_id': ObjectId('650dc8bcc6437c704718623e'),
#   'FHRSID': 830367,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000073570',
#   'BusinessName': 'Genesis',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Basement',
#   'AddressLine2': '136 Sandgate Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2BY',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2016-01-12T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.173056', 'latitude': '51.077492'},
#   'RightToReply': '',
#   'Distance': 4592.350634094116,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/830367'}]},
#  {'_id': ObjectId('650dc8bcc6437c704718623f'),
#   'FHRSID': 1466486,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000078151',
#   'BusinessName': 'Waves Coffee House',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': '1B Town Walk',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'PostCode': 'CT20 2AD',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2021-11-24T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.175811', 'latitude': '51.078515'},
#   'RightToReply': '',
#   'Distance': 4592.2886201108895,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/1466486'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047186240'),
#   'FHRSID': 973104,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000075292',
#   'BusinessName': 'Annapurna',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'AddressLine1': 'Ground Floor Business Premises',
#   'AddressLine2': '15 Cheriton Place',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT20 2AY',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-07-25T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.17584', 'latitude': '51.07873'},
#   'RightToReply': '',
#   'Distance': 4592.295632854469,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/973104'}]},
#  {'_id': ObjectId('650dc8bcc6437c7047186241'),
#   'FHRSID': 359015,
#   'ChangesByServerID': 0,
#   'LocalAuthorityBusinessID': 'PI/000022751',
#   'BusinessName': 'Little Acorns Pre-School',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'AddressLine1': 'Folkestone Baptist Church',
#   'AddressLine2': 'Hill Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'PostCode': 'CT19 6LY',
#   'Phone': '',
#   'RatingValue': {'$toInt': '$RatingValue'},
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingDate': '2019-10-03T00:00:00',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#   'SchemeType': 'FHRS',
#   'geocode': {'longitude': '1.189834', 'latitude': '51.09221'},
#   'RightToReply': '',
#   'Distance': 4592.291820408164,
#   'NewRatingPending': False,
#   'meta': {'dataSource': None,
#    'extractDate': '0001-01-01T00:00:00',
#    'itemCount': 0,
#    'returncode': None,
#    'totalCount': 0,
#    'totalPages': 0,
#    'pageSize': 0,
#    'pageNumber': 0},
#   'links': [{'rel': 'self',
#     'href': 'https://api.ratings.food.gov.uk/establishments/359015'}]},
#  ...]

# %%
db.establishments.count_documents({})
# Out:
# 39779

# %%
[x for x in db.establishments.find()][0]
# Out:
# {'_id': ObjectId('650dc8bcc6437c7047185e5a'),
#  'FHRSID': 1034540,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000078691',
#  'BusinessName': 'The Coastguard Inn',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'The Bay',
#  'AddressLine2': 'St Margarets Bay',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT15 6DY',
#  'Phone': '',
#  'RatingValue': {'$toInt': '$RatingValue'},
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2022-08-17T00:00:00',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.387974', 'latitude': '51.152225'},
#  'RightToReply': '',
#  'Distance': 4587.347174863443,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1034540'}]}

# %%
# Find the establishments with a hygiene score of 20
query ={
        "$match": {
            "score.Hygiene": 20  
        }
    }

results = db.establishments_collection.find(query)

# Use count_documents to display the number of documents in the result
count = db.establishments_collection.count_documents(query)
print("Number of establishments with a hygiene score of 20:", count)

# Display the first document in the results using pprint
pprint(list(results))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[108], line 11
#       8 results = db.establishments_collection.find(query)
#      10 # Use count_documents to display the number of documents in the result
# ---> 11 count = db.establishments_collection.count_documents(query)
#      12 print("Number of establishments with a hygiene score of 20:", count)
#      14 # Display the first document in the results using pprint
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:1826, in Collection.count_documents(self, filter, session, **kwargs)
#    1823         return 0
#    1824     return result['n']
# -> 1826 return self.__database.client._retryable_read(
#    1827     _cmd, self._read_preference_for(session), session)
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:1820, in Collection.count_documents.<locals>._cmd(session, server, sock_info, secondary_ok)
#    1819 def _cmd(session, server, sock_info, secondary_ok):
# -> 1820     result = self._aggregate_one_result(
#    1821         sock_info, secondary_ok, cmd, collation, session)
#    1822     if not result:
#    1823         return 0
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:1685, in Collection._aggregate_one_result(self, sock_info, secondary_ok, cmd, collation, session)
#    1682 def _aggregate_one_result(
#    1683         self, sock_info, secondary_ok, cmd, collation, session):
#    1684     """Internal helper to run an aggregate that returns a single result."""
# -> 1685     result = self._command(
#    1686         sock_info,
#    1687         cmd,
#    1688         secondary_ok,
#    1689         allowable_errors=[26],  # Ignore NamespaceNotFound.
#    1690         codec_options=self.__write_response_codec_options,
#    1691         read_concern=self.read_concern,
#    1692         collation=collation,
#    1693         session=session)
#    1694     # cursor will not be present for NamespaceNotFound errors.
#    1695     if 'cursor' not in result:
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:238, in Collection._command(self, sock_info, command, secondary_ok, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, collation, session, retryable_write, user_fields)
#     209 """Internal command helper.
#     210
#     211 :Parameters:
#    (...)
#     235   The result document.
#     236 """
#     237 with self.__database.client._tmp_session(session) as s:
# --> 238     return sock_info.command(
#     239         self.__database.name,
#     240         command,
#     241         secondary_ok,
#     242         read_preference or self._read_preference_for(session),
#     243         codec_options or self.codec_options,
#     244         check,
#     245         allowable_errors,
#     246         read_concern=read_concern,
#     247         write_concern=write_concern,
#     248         parse_write_concern_error=True,
#     249         collation=collation,
#     250         session=s,
#     251         client=self.__database.client,
#     252         retryable_write=retryable_write,
#     253         user_fields=user_fields)
#
# File ~\anaconda3\lib\site-packages\pymongo\pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~\anaconda3\lib\site-packages\pymongo\network.py:158, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156             client._process_response(response_doc, session)
#     157         if check:
# --> 158             helpers._check_command_response(
#     159                 response_doc, sock_info.max_wire_version, allowable_errors,
#     160                 parse_write_concern_error=parse_write_concern_error)
#     161 except Exception as exc:
#     162     if publish:
#
# File ~\anaconda3\lib\site-packages\pymongo\helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: unknown top level operator: $match. If you have a field name that starts with a '$' symbol, consider using $getField or $setField., full error: {'ok': 0.0, 'errmsg': "unknown top level operator: $match. If you have a field name that starts with a '$' symbol, consider using $getField or $setField.", 'code': 2, 'codeName': 'BadValue'}

# %%
import pandas as pd
pd.DataFrame(list(results))

results = db.establishments.aggregate(query)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 4
#       1 import pandas as pd
#       2 pd.DataFrame(list(results))
# ----> 4 results = db.establishments.aggregate(query)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:2496, in Collection.aggregate(self, pipeline, session, **kwargs)
#    2423 """Perform an aggregation using the aggregation framework on this
#    2424 collection.
#    2425
#    (...)
#    2493     https://docs.mongodb.com/manual/reference/command/aggregate
#    2494 """
#    2495 with self.__database.client._tmp_session(session, close=False) as s:
# -> 2496     return self._aggregate(_CollectionAggregationCommand,
#    2497                            pipeline,
#    2498                            CommandCursor,
#    2499                            session=s,
#    2500                            explicit_session=session is not None,
#    2501                            **kwargs)
#
# File ~\anaconda3\lib\site-packages\pymongo\collection.py:2415, in Collection._aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2408     warnings.warn(
#    2409         "The useCursor option is deprecated "
#    2410         "and will be removed in PyMongo 4.0",
#    2411         DeprecationWarning, stacklevel=2)
#    2412     use_cursor = common.validate_boolean(
#    2413         "useCursor", kwargs.pop("useCursor", True))
# -> 2415 cmd = aggregation_command(
#    2416     self, cursor_class, pipeline, kwargs, explicit_session,
#    2417     user_fields={'cursor': {'firstBatch': 1}}, use_cursor=use_cursor)
#    2418 return self.__database.client._retryable_read(
#    2419     cmd.get_cursor, cmd.get_read_preference(session), session,
#    2420     retryable=not cmd._performs_write)
#
# File ~\anaconda3\lib\site-packages\pymongo\aggregation.py:178, in _CollectionAggregationCommand.__init__(self, *args, **kwargs)
#     175 def __init__(self, *args, **kwargs):
#     176     # Pop additional option and initialize parent class.
#     177     use_cursor = kwargs.pop("use_cursor", True)
# --> 178     super(_CollectionAggregationCommand, self).__init__(*args, **kwargs)
#     180     # Remove the cursor document if the user has set use_cursor to False.
#     181     self._use_cursor = use_cursor
#
# File ~\anaconda3\lib\site-packages\pymongo\aggregation.py:40, in _AggregationCommand.__init__(self, target, cursor_class, pipeline, options, explicit_session, user_fields, result_processor)
#      35     raise ConfigurationError("The explain option is not supported. "
#      36                              "Use Database.command instead.")
#      38 self._target = target
# ---> 40 common.validate_list('pipeline', pipeline)
#      41 self._pipeline = pipeline
#      42 self._performs_write = False
#
# File ~\anaconda3\lib\site-packages\pymongo\common.py:473, in validate_list(option, value)
#     471 """Validates that 'value' is a list."""
#     472 if not isinstance(value, list):
# --> 473     raise TypeError("%s must be a list" % (option,))
#     474 return value
#
# TypeError: pipeline must be a list

# %%
df = pd.DataFrame(list(results))
df
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 df = pd.DataFrame(list(results))
#       2 df
#
# File ~\anaconda3\lib\site-packages\pymongo\cursor.py:1238, in Cursor.next(self)
#    1236 if self.__empty:
#    1237     raise StopIteration
# -> 1238 if len(self.__data) or self._refresh():
#    1239     if self.__manipulate:
#    1240         _db = self.__collection.database
#
# File ~\anaconda3\lib\site-packages\pymongo\cursor.py:1155, in Cursor._refresh(self)
#    1134         warnings.warn("using a min/max query operator without "
#    1135                       "specifying a Cursor.hint is deprecated. A "
#    1136                       "hint will be required when using min/max in "
#    1137                       "PyMongo 4.0",
#    1138                       DeprecationWarning, stacklevel=3)
#    1139     q = self._query_class(self.__query_flags,
#    1140                           self.__collection.database.name,
#    1141                           self.__collection.name,
#    (...)
#    1153                           self.__allow_disk_use,
#    1154                           self.__exhaust)
# -> 1155     self.__send_message(q)
#    1156 elif self.__id:  # Get More
#    1157     if self.__limit:
#
# File ~\anaconda3\lib\site-packages\pymongo\cursor.py:1044, in Cursor.__send_message(self, operation)
#    1040     raise InvalidOperation(
#    1041         "exhaust cursors do not support auto encryption")
#    1043 try:
# -> 1044     response = client._run_operation(
#    1045         operation, self._unpack_response, address=self.__address)
#    1046 except OperationFailure as exc:
#    1047     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1048         # Don't send killCursors because the cursor is already closed.
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1424, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
#    1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
# -> 1424 return self._retryable_read(
#    1425     _cmd, operation.read_preference, operation.session,
#    1426     address=address, retryable=isinstance(operation, message._Query))
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1525, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1521         if retrying and not retryable:
#    1522             # A retry is not possible because this server does
#    1523             # not support retryable reads, raise the last error.
#    1524             raise last_error
# -> 1525         return func(session, server, sock_info, secondary_ok)
#    1526 except ServerSelectionTimeoutError:
#    1527     if retrying:
#    1528         # The application may think the write was never attempted
#    1529         # if we raise ServerSelectionTimeoutError on the retry
#    1530         # attempt. Raise the original exception instead.
#
# File ~\anaconda3\lib\site-packages\pymongo\mongo_client.py:1420, in MongoClient._run_operation.<locals>._cmd(session, server, sock_info, secondary_ok)
#    1419 def _cmd(session, server, sock_info, secondary_ok):
# -> 1420     return server.run_operation(
#    1421         sock_info, operation, secondary_ok, self._event_listeners,
#    1422         unpack_res)
#
# File ~\anaconda3\lib\site-packages\pymongo\server.py:130, in Server.run_operation(self, sock_info, operation, set_secondary_okay, listeners, unpack_res)
#     128         first = docs[0]
#     129         operation.client._process_response(first, operation.session)
# --> 130         _check_command_response(first, sock_info.max_wire_version)
#     131 except Exception as exc:
#     132     if publish:
#
# File ~\anaconda3\lib\site-packages\pymongo\helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: unknown top level operator: $match. If you have a field name that starts with a '$' symbol, consider using $getField or $setField., full error: {'ok': 0.0, 'errmsg': "unknown top level operator: $match. If you have a field name that starts with a '$' symbol, consider using $getField or $setField.", 'code': 2, 'codeName': 'BadValue'}

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query =

# Use count_documents to display the number of documents in the result

# Display the first document in the results using pprint

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 
longitude = 

query = 
sort =  

# Print the results

# %%
# Convert result to Pandas DataFrame

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

# %%
# Convert the result to a Pandas DataFrame

# Display the number of rows in the DataFrame

# Display the first 10 rows of the DataFrame
