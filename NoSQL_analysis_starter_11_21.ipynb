# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collections = db.list_collection_names()

# Print the collections
pprint(collections)
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = db.establishments.find({'scores.Hygiene': 20})
results = [query]

# Use count_documents to display the number of documents in the result
scoreTwenty = db.establishments.count_documents({'scores.Hygiene': 20})

print(f"Number of establishments with a hygiene score of 20: {scoreTwenty}")
print(f'-'*50)

# Display the first document in the results using pprint
pprint(establishments.find_one({'scores.Hygiene': 20}))
print(f'-'*50)
# Out:
# Number of establishments with a hygiene score of 20: 41
# --------------------------------------------------
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('655d17c760839370efb16e49'),
# ...

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame
df_result = pd.DataFrame(list(db.establishments.find({'scores.Hygiene': 20})))

# Display the number of rows in the DataFrame
num_rows = len(df_result)
print(f"Number of rows in the DataFrame: {num_rows}")
print(f'-'*50)

# Display the first 10 rows of the DataFrame
df_result.head(10)
# Out:
# Number of rows in the DataFrame: 41
# --------------------------------------------------
#                         _id   FHRSID  ChangesByServerID  \
# 0  655d17c760839370efb16e49   110681                  0
# 1  655d17c760839370efb171ca   612039                  0
# 2  655d17c760839370efb174d4   730933                  0
# 3  655d17c760839370efb176c2   172735                  0
# 4  655d17c760839370efb176d1   172953                  0
# 5  655d17c860839370efb18070   512854                  0
# 6  655d17c860839370efb18291  1537089                  0
# 7  655d17c960839370efb197bc   155648                  0
# 8  655d17c960839370efb19c00  1012883                  0
# 9  655d17c960839370efb1a412   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Check the number of establishments in London
count_london = db.establishments.count_documents({'LocalAuthorityName': {'$regex': 'London', '$options': 'i'}})
print(f"Number of establishments in London: {count_london}")
# Out:
# Number of establishments in London: 37

# %%
# Find the establishments with London as the Local Authority and RatingValue >= 4
query = db.establishments.find({
    'LocalAuthorityName': {'$regex': 'London', '$options': 'i'},
    'scores.Hygiene': {'$gte': 4}
})

# Use count_documents to display the number of documents in the result
count_of_documents = db.establishments.count_documents({
    'LocalAuthorityName': {'$regex': 'London', '$options': 'i'},
    'scores.Hygiene': {'$gte': 4}
})

print(f"Number of establishments in London with RatingValue >= 4: {count_of_documents}")
print(f'-' * 50)

# Display the first document in the results using pprint
pprint(db.establishments.find_one({
    'LocalAuthorityName': {'$regex': 'London', '$options': 'i'},
    'scores.Hygiene': {'$gte': 4}
}))
print('-' * 50)
# Out:
# Number of establishments in London with RatingValue >= 4: 8
# --------------------------------------------------
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('655d17c860839370efb18864'),
# ...

# %%
import pandas as pd
# Convert the result to a Pandas DataFrame
df_result = pd.DataFrame(list(db.establishments.find({
    'LocalAuthorityName': {'$regex': 'London', '$options': 'i'},
    'scores.Hygiene': {'$gte': 4}
})))

# Display the number of rows in the DataFrame
num_rows = len(df_result)
print(f"Number of rows in the DataFrame: {num_rows}")
print(f'-'*50)

# Display the first 10 rows of the DataFrame
df_result.head(10)
# Out:
# Number of rows in the DataFrame: 8
# --------------------------------------------------
#                         _id   FHRSID  ChangesByServerID  \
# 0  655d17c860839370efb18864   621707                  0
# 1  655d17c960839370efb19ce4  1523645                  0
# 2  655d17cb60839370efb1d0b5   878523                  0
# 3  655d17cb60839370efb1d0b7   902473                  0
# 4  655d17cb60839370efb1d0d2   295105                  0
# 5  655d17cb60839370efb1d2b0   294616                  0
# 6  655d17cb60839370efb1d550  1427985                  0
# 7  655d17cb60839370efb1d75b   934211                  0
#
#   LocalAuthorityBusinessID            BusinessName  \
# 0             PI/000025307               Charlie's
# 1             PI/000038853         Gourmet Kitchen
# 2             PI/000029844        Brick Lane Brews
# 3             PI/000029852           Pret A Manger
# 4             PI/000020747               Cabin Bar
# 5             PI/000016269              Caffè Nero
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score
lat_long = establishments.find_one({"BusinessName":"Penang Flavours"},{"geocode":1})

degree_search = 0.01
latitude = lat_long['geocode']['latitude']
longitude = lat_long['geocode']['longitude']

query = {"geocode.latitude":{'$gte': latitude-degree_search, '$lte': latitude+degree_search},
        "geocode.longitude":{'$gte': longitude-degree_search, '$lte': longitude+degree_search},
        "RatingValue":5}
sort =  [("scores.Hygiene",1)]
limit = 5

# Print the results
results = list(establishments.find(query).sort(sort).limit(limit))
for r in results:
    pprint(r)
# Out:
# {'AddressLine1': '130 - 132 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Volunteer',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4646.965634598608,
#  'FHRSID': 694609,
#  'LocalAuthorityBusinessID': 'PI/000116619',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2019-08-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('655d17ca60839370efb1c6a8'),
#  'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
# ...

# %%
# Convert result to Pandas DataFrame
near_penang_df = pd.json_normalize(results)

# Export DataFrame to csv file
near_penang_df.to_csv("near_penang_df.csv", index=False, header=True)

near_penang_df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  655d17ca60839370efb1c6a8   694609                  0
# 1  655d17ca60839370efb1c6c0   695241                  0
# 2  655d17ca60839370efb1c6c3   694478                  0
# 3  655d17ca60839370efb1c67b   695223                  0
# 4  655d17ca60839370efb1c68b  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000086506                    Atlantic Fish Bar
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2                 Takeaway/sandwich shop            7844
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Pipeline
match = {'$match': {"scores.Hygiene":0}}

group = {'$group': {"_id" : "$LocalAuthorityName",
                   "count": {'$sum':1}}}

sort = {'$sort':{"count":-1}}

pipeline = [match, group, sort]

results = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(f"There are {len(results)} documents in the result.")

# Print the first 10 results
print("")
print("The first 10 documents are:")
print("-"*50)
pprint(results[0:10])
# Out:
# There are 55 documents in the result.
#
# The first 10 documents are:
# --------------------------------------------------
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
agg_df = pd.json_normalize(results)

# Export DataFrame to csv file
agg_df.to_csv("aggregate_df.csv", index=False, header=True)

# Display the number of rows in the DataFrame
print(f"The number of rows in this DataFrame is: {len(agg_df)}")
print("")

# Display the first 10 rows of the DataFrame
agg_df.head(10)
# Out:
# The number of rows in this DataFrame is: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
